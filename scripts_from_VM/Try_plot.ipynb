# %%
import zarr

# %%
out = zarr.open('output_file.zarr')

# %%
out.lon ## time_len, particles #
# Out:
# <zarr.core.Array '/lon' (25, 97) float32>

# %%
out.lon[0] ### time in seconds cont
# Out:
# array([6.       , 6.0004296, 6.0017195, 6.003873 , 6.0068946, 6.0103955,
#        6.013982 , 6.0176544, 6.0214143, 6.0252542, 6.0291677, 6.033155 ,
#        6.0372167, 6.0413413, 6.0455174, 6.049745 , 6.054025 , 6.058344 ,
#        6.0626864, 6.0670533, 6.0714445, 6.0758495, 6.0802574, 6.084668 ,
#        6.089083 , 6.093494 , 6.097891 , 6.1022735, 6.106642 , 6.110991 ,
#        6.1153164, 6.1196175, 6.1238933, 6.128145 , 6.132374 , 6.1365786,
#        6.1407585, 6.144925 , 6.149091 , 6.153254 , 6.1574144, 6.161571 ,
#        6.165723 , 6.169871 , 6.174017 , 6.178172 , 6.182348 , 6.1865435,
#        6.1907587, 6.195001 , 6.199279 , 6.2035913, 6.2079387, 6.212328 ,
#        6.216767 , 6.221256 , 6.2257953, 6.23039  , 6.2350454, 6.2397623,
#        6.244541 , 6.2493834, 6.254292 , 6.2592683, 6.264313 , 6.269416 ,
#        6.2745657, 6.279763 , 6.285009 , 6.29029  , 6.2955937, 6.30092  ,
#        6.306269 , 6.3116193, 6.3169484, 6.3222566, 6.3275437, 6.3327937,
# ...

# %%
out.lon
# Out:
# <zarr.core.Array '/lon' (25, 97) float32>

# %%
out.lon[:,0] # time_0
# Out:
# array([ 6.,  8., 10., 12., 14.,  6.,  8., 10., 12., 14.,  6.,  8., 10.,
#        12., 14.,  6.,  8., 10., 12., 14.,  6.,  8., 10., 12., 14.],
#       dtype=float32)

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /home/hacker/miniconda3/envs/lost_hackathon/lib/python3.10/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
plt.scatter(out.lon,out.lat)
plt.scatter(np.nanmean(out.lon,axis=0), np.nanmean(out.lat,axis=0))##radis =4

# %%
    fig, ax= plt.subplots(1, figsize=[10,3]) 
    
    img0 = ax.imshow(odata.uo[11][0], extent=(odata.longitude.min().values, odata.longitude.max().values, odata.latitude.min().values, odata.latitude.max().values), origin='lower')
    plt.colorbar(img0, ax=ax)
    
    ax.plot([5], [-15], 'r.')
#    ax.plot([move_data.move_lon[i]], [move_data.move_lat[i]], 'r.')

# %%
out.time
# Out:
# <zarr.core.Array '/time' (25, 97) float64>

# %%
193/2
# Out:
# 96.5

# %%
481/5
# Out:
# 96.2

# %%
# Out:
# 4.041666666666667

# %%
from datetime import datetime

datetime.fromtimestamp(out.time[0]).strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [88], line 3
#       1 from datetime import datetime
# ----> 3 datetime.fromtimestamp(out.time[0]).strftime('%Y-%m-%d')
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
df = pd.DataFrame({'lon':a, 'lat':b, 'time':})
df.to_csv('out.csv', index=False)
outt = pd.read_csv('out.csv')

# %%
outt = pd.read_csv('out.csv')
outt
# Out:
#           lon        lat
# 0    6.437984 -48.965763
# 1    8.221025 -48.930126
# 2   10.250667 -49.097160
# 3   12.351275 -48.957077
# 4   14.392130 -49.176850
# 5    6.264614 -47.048130
# 6    8.250489 -47.033510
# 7   10.398401 -47.039253
# 8   12.493612 -47.012543
# 9   14.355214 -47.016396
# 10   6.268432 -45.002136
# 11   7.963503 -45.137783
# 12  10.482843 -45.110752
# 13  12.189466 -45.010677
# 14  14.346459 -45.000740
# 15   6.166404 -43.040924
# 16   8.127611 -43.030490
# 17  10.186114 -42.980390
# 18  12.517564 -43.125122
# 19  14.114590 -43.039790
# 20   6.225092 -41.097565
# 21   7.866054 -40.978348
# 22   9.821288 -40.832030
# 23  12.334699 -40.641273
# 24  14.215780 -41.065120

# %%
st.button("longitute")
# Out:
# False

# %%
a = []
b = []

for i in range(len(out.lon)):
    a.append(np.mean(out.lon[i]))
    b.append(np.mean(out.lat[i]))

# %%
out.time
# Out:
# <zarr.core.Array '/time' (25, 193) float64>

# %%
plt.plot(out.lon[0])#, out.lat[0])

# %%
print(len(wdata.longitude), len(odata.longitude))

for i in range(len(wdata.longitude)):
    print(wdata.longitude[i].values, odata.longitude[i].values)
# Out:
# 161 481
# 0.0 0.0
# 0.25 0.083333336
# 0.5 0.16666667
# 0.75 0.25
# 1.0 0.33333334
# 1.25 0.41666666
# 1.5 0.5
# 1.75 0.5833333
# 2.0 0.6666667
# 2.25 0.75
# 2.5 0.8333333
# 2.75 0.9166667
# 3.0 1.0
# 3.25 1.0833334
# 3.5 1.1666666
# 3.75 1.25
# 4.0 1.3333334
# 4.25 1.4166666
# 4.5 1.5
# 4.75 1.5833334
# 5.0 1.6666666
# 5.25 1.75
# 5.5 1.8333334
# 5.75 1.9166666
# 6.0 2.0
# 6.25 2.0833333
# 6.5 2.1666667
# 6.75 2.25
# 7.0 2.3333333
# 7.25 2.4166667
# 7.5 2.5
# 7.75 2.5833333
# 8.0 2.6666667
# 8.25 2.75
# 8.5 2.8333333
# 8.75 2.9166667
# 9.0 3.0
# 9.25 3.0833333
# 9.5 3.1666667
# 9.75 3.25
# 10.0 3.3333333
# 10.25 3.4166667
# 10.5 3.5
# 10.75 3.5833333
# 11.0 3.6666667
# 11.25 3.75
# 11.5 3.8333333
# 11.75 3.9166667
# 12.0 4.0
# 12.25 4.0833335
# 12.5 4.1666665
# 12.75 4.25
# 13.0 4.3333335
# 13.25 4.4166665
# 13.5 4.5
# 13.75 4.5833335
# 14.0 4.6666665
# 14.25 4.75
# 14.5 4.8333335
# 14.75 4.9166665
# 15.0 5.0
# 15.25 5.0833335
# 15.5 5.1666665
# 15.75 5.25
# 16.0 5.3333335
# ...

# %%
wdata.longitude
# Out:
# <xarray.DataArray 'longitude' (longitude: 161)>
# array([ 0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,  1.75,  2.  ,  2.25,
#         2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,  4.  ,  4.25,  4.5 ,  4.75,
#         5.  ,  5.25,  5.5 ,  5.75,  6.  ,  6.25,  6.5 ,  6.75,  7.  ,  7.25,
#         7.5 ,  7.75,  8.  ,  8.25,  8.5 ,  8.75,  9.  ,  9.25,  9.5 ,  9.75,
#        10.  , 10.25, 10.5 , 10.75, 11.  , 11.25, 11.5 , 11.75, 12.  , 12.25,
#        12.5 , 12.75, 13.  , 13.25, 13.5 , 13.75, 14.  , 14.25, 14.5 , 14.75,
#        15.  , 15.25, 15.5 , 15.75, 16.  , 16.25, 16.5 , 16.75, 17.  , 17.25,
#        17.5 , 17.75, 18.  , 18.25, 18.5 , 18.75, 19.  , 19.25, 19.5 , 19.75,
#        20.  , 20.25, 20.5 , 20.75, 21.  , 21.25, 21.5 , 21.75, 22.  , 22.25,
#        22.5 , 22.75, 23.  , 23.25, 23.5 , 23.75, 24.  , 24.25, 24.5 , 24.75,
#        25.  , 25.25, 25.5 , 25.75, 26.  , 26.25, 26.5 , 26.75, 27.  , 27.25,
#        27.5 , 27.75, 28.  , 28.25, 28.5 , 28.75, 29.  , 29.25, 29.5 , 29.75,
# ...

# %%
plt.plot(odata.longitude, 'r')
plt.plot(wdata.longitude, 'b')

# %%
odata.time.values
# Out:
# array(['2021-05-15T00:00:00.000000000', '2021-05-15T01:00:00.000000000',
#        '2021-05-15T02:00:00.000000000', '2021-05-15T03:00:00.000000000',
#        '2021-05-15T04:00:00.000000000', '2021-05-15T05:00:00.000000000',
#        '2021-05-15T06:00:00.000000000', '2021-05-15T07:00:00.000000000',
#        '2021-05-15T08:00:00.000000000', '2021-05-15T09:00:00.000000000',
#        '2021-05-15T10:00:00.000000000', '2021-05-15T11:00:00.000000000',
#        '2021-05-15T12:00:00.000000000', '2021-05-15T13:00:00.000000000',
#        '2021-05-15T14:00:00.000000000', '2021-05-15T15:00:00.000000000',
#        '2021-05-15T16:00:00.000000000', '2021-05-15T17:00:00.000000000',
#        '2021-05-15T18:00:00.000000000', '2021-05-15T19:00:00.000000000',
#        '2021-05-15T20:00:00.000000000', '2021-05-15T21:00:00.000000000',
#        '2021-05-15T22:00:00.000000000', '2021-05-15T23:00:00.000000000',
#        '2021-05-16T00:00:00.000000000', '2021-05-16T01:00:00.000000000',
# ...

# %%
wdata.time.values
# Out:
# array(['2021-05-15T00:00:00.000000000', '2021-05-15T01:00:00.000000000',
#        '2021-05-15T02:00:00.000000000', '2021-05-15T03:00:00.000000000',
#        '2021-05-15T04:00:00.000000000', '2021-05-15T05:00:00.000000000',
#        '2021-05-15T06:00:00.000000000', '2021-05-15T07:00:00.000000000',
#        '2021-05-15T08:00:00.000000000', '2021-05-15T09:00:00.000000000',
#        '2021-05-15T10:00:00.000000000', '2021-05-15T11:00:00.000000000',
#        '2021-05-15T12:00:00.000000000', '2021-05-15T13:00:00.000000000',
#        '2021-05-15T14:00:00.000000000', '2021-05-15T15:00:00.000000000',
#        '2021-05-15T16:00:00.000000000', '2021-05-15T17:00:00.000000000',
#        '2021-05-15T18:00:00.000000000', '2021-05-15T19:00:00.000000000',
#        '2021-05-15T20:00:00.000000000', '2021-05-15T21:00:00.000000000',
#        '2021-05-15T22:00:00.000000000', '2021-05-15T23:00:00.000000000',
#        '2021-05-16T00:00:00.000000000', '2021-05-16T01:00:00.000000000',
# ...

# %%
out.time
# Out:
# <zarr.core.Array '/time' (25, 193) float64>

# %%
out.time[0]
# Out:
# array([     0.,    900.,   1800.,   2700.,   3600.,   4500.,   5400.,
#          6300.,   7200.,   8100.,   9000.,   9900.,  10800.,  11700.,
#         12600.,  13500.,  14400.,  15300.,  16200.,  17100.,  18000.,
#         18900.,  19800.,  20700.,  21600.,  22500.,  23400.,  24300.,
#         25200.,  26100.,  27000.,  27900.,  28800.,  29700.,  30600.,
#         31500.,  32400.,  33300.,  34200.,  35100.,  36000.,  36900.,
#         37800.,  38700.,  39600.,  40500.,  41400.,  42300.,  43200.,
#         44100.,  45000.,  45900.,  46800.,  47700.,  48600.,  49500.,
#         50400.,  51300.,  52200.,  53100.,  54000.,  54900.,  55800.,
#         56700.,  57600.,  58500.,  59400.,  60300.,  61200.,  62100.,
#         63000.,  63900.,  64800.,  65700.,  66600.,  67500.,  68400.,
#         69300.,  70200.,  71100.,  72000.,  72900.,  73800.,  74700.,
#         75600.,  76500.,  77400.,  78300.,  79200.,  80100.,  81000.,
# ...

# %%
out.time[1]
# Out:
# array([     0.,    900.,   1800.,   2700.,   3600.,   4500.,   5400.,
#          6300.,   7200.,   8100.,   9000.,   9900.,  10800.,  11700.,
#         12600.,  13500.,  14400.,  15300.,  16200.,  17100.,  18000.,
#         18900.,  19800.,  20700.,  21600.,  22500.,  23400.,  24300.,
#         25200.,  26100.,  27000.,  27900.,  28800.,  29700.,  30600.,
#         31500.,  32400.,  33300.,  34200.,  35100.,  36000.,  36900.,
#         37800.,  38700.,  39600.,  40500.,  41400.,  42300.,  43200.,
#         44100.,  45000.,  45900.,  46800.,  47700.,  48600.,  49500.,
#         50400.,  51300.,  52200.,  53100.,  54000.,  54900.,  55800.,
#         56700.,  57600.,  58500.,  59400.,  60300.,  61200.,  62100.,
#         63000.,  63900.,  64800.,  65700.,  66600.,  67500.,  68400.,
#         69300.,  70200.,  71100.,  72000.,  72900.,  73800.,  74700.,
#         75600.,  76500.,  77400.,  78300.,  79200.,  80100.,  81000.,
# ...

# %%
odata = xr.open_dataset('~/app/data/cmems_interp.nc')

# %%
odata
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 481, depth: 1, latitude: 481, time: 264)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.08333 0.1667 0.25 ... 39.83 39.92 40.0
#   * depth      (depth) float32 0.494
#   * latitude   (latitude) float32 -50.0 -49.92 -49.83 ... -10.17 -10.08 -10.0
#   * time       (time) datetime64[ns] 2021-05-15 ... 2021-05-25T23:00:00
# Data variables:
#     uo         (time, depth, latitude, longitude) float64 ...
#     vo         (time, depth, latitude, longitude) float64 ...
# Attributes: (12/25)
#     title:                              hourly mean fields from Global Ocean ...
#     easting:                            longitude
#     northing:                           latitude
#     history:                            2022/11/28 00:04:09 MERCATOR OCEAN Ne...
#     source:                             MERCATOR PSY4QV3R1
#     institution:                        MERCATOR OCEAN
#     ...                                 ...
# ...

# %%
    fig, ax= plt.subplots(1, figsize=[10,3]) 
    
    img0 = ax.imshow(odata.uo[11][0], extent=(odata.longitude.min().values, odata.longitude.max().values, odata.latitude.min().values, odata.latitude.max().values), origin='lower')
    plt.colorbar(img0, ax=ax)
    
    ax.plot([5], [-15], 'r.')
#    ax.plot([move_data.move_lon[i]], [move_data.move_lat[i]], 'r.')

# %%
wdata.time.loc['2021/05/15 00:00:00']
# Out:
# <xarray.DataArray 'time' ()>
# array('2021-05-15T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 2021-05-15
# Attributes:
#     long_name:  time

# %%
wdata
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 161, latitude: 161, time: 264)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 39.25 39.5 39.75 40.0
#   * latitude   (latitude) float32 -10.0 -10.25 -10.5 ... -49.5 -49.75 -50.0
#   * time       (time) datetime64[ns] 2021-05-15 ... 2021-05-25T23:00:00
# Data variables:
#     u10        (time, latitude, longitude) float32 -2.263 -2.413 ... 2.572 2.648
#     v10        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-11-28 09:47:05 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
if time_real_data == time_output:
    plot(map)
    put(output_point(lon, lat))
# Out:
#   Cell In [101], line 1
#     if time_real_data == time_output
#                                     ^
# SyntaxError: expected ':'

# %%
if time_x == output_time_x:
    
    fig, ax= plt.subplots(1, figsize=[10,3]) 
    
    img0 = ax.imshow(wdata.u10[time_x], extent=(wdata.longitude.min().values, wdata.longitude.max().values, wdata.latitude.min().values, wdata.latitude.max().values), origin='upper')
    plt.colorbar(img0, ax=ax)
    
    ax.plot([mean_output_lon[output_time_x]], [mean_output_latitude[output_time_x]], 'r.')
#    ax.plot([move_data.move_lon[i]], [move_data.move_lat[i]], 'r.')

# %%
    fig, ax= plt.subplots(1, figsize=[10,3]) 
    
    img0 = ax.imshow(wdata.u10[0], extent=(wdata.longitude.min().values, wdata.longitude.max().values, wdata.latitude.min().values, wdata.latitude.max().values), origin='upper')
    plt.colorbar(img0, ax=ax)
    
    ax.plot([5], [-15], 'r.')
#    ax.plot([move_data.move_lon[i]], [move_data.move_lat[i]], 'r.')

# %%
wdata
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 161, latitude: 161, time: 264)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 39.25 39.5 39.75 40.0
#   * latitude   (latitude) float32 -10.0 -10.25 -10.5 ... -49.5 -49.75 -50.0
#   * time       (time) datetime64[ns] 2021-05-15 ... 2021-05-25T23:00:00
# Data variables:
#     u10        (time, latitude, longitude) float32 ...
#     v10        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-11-28 09:47:05 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
wdata.u10[0].min().values
# Out:
# array(-8.503161, dtype=float32)

# %%
import xarray as xr

# %%
wdata = xr.open_dataset('~/app/data/era5.nc')

# %%
wdata
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 161, latitude: 161, time: 264)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 39.25 39.5 39.75 40.0
#   * latitude   (latitude) float32 -10.0 -10.25 -10.5 ... -49.5 -49.75 -50.0
#   * time       (time) datetime64[ns] 2021-05-15 ... 2021-05-25T23:00:00
# Data variables:
#     u10        (time, latitude, longitude) float32 ...
#     v10        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-11-28 09:47:05 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
wdata.time
# Out:
# <xarray.DataArray 'time' (time: 264)>
# array(['2021-05-15T00:00:00.000000000', '2021-05-15T01:00:00.000000000',
#        '2021-05-15T02:00:00.000000000', ..., '2021-05-25T21:00:00.000000000',
#        '2021-05-25T22:00:00.000000000', '2021-05-25T23:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2021-05-15 ... 2021-05-25T23:00:00
# Attributes:
#     long_name:  time

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(odata.u10[0])

# %%
plt.quiver(wdata.u10[0], wdata.v10[0])

# %%
import seaborn as sns

# %%
sns.displot(wdata.u10[0])

# %%
imshow(wdata.uo[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 imshow(wdata.uo[0])
#
# NameError: name 'imshow' is not defined
